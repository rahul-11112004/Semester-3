# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\CSES134\\Downloads\\tesla_stock_data.csv")

# %%
data
# Out:
#            Date  Year        Open        High         Low       Close  \
# 0    2020-01-02  2020   28.299999   28.713333   28.114000   28.684000
# 1    2020-01-03  2020   29.366667   30.266666   29.128000   29.534000
# 2    2020-01-06  2020   29.364668   30.104000   29.333332   30.102667
# 3    2020-01-07  2020   30.760000   31.441999   30.224001   31.270666
# 4    2020-01-08  2020   31.580000   33.232666   31.215334   32.809334
# ..          ...   ...         ...         ...         ...         ...
# 991  2023-12-22  2023  256.760010  258.220001  251.369995  252.539993
# 992  2023-12-26  2023  254.490005  257.970001  252.910004  256.609985
# 993  2023-12-27  2023  258.350006  263.339996  257.519989  261.440002
# 994  2023-12-28  2023  263.660004  265.130005  252.710007  253.179993
# 995  2023-12-29  2023  255.100006  255.190002  247.429993  248.479996
#
#         Volume   Adj Close
# 0    142981500   28.684000
# 1    266677500   29.534000
# 2    151995000   30.102667
# ...

# %%
pt.scatter(data["Year"][:5],data["High"][:5],data["Low"][:5])

# %%
pt.pie(data["Close"][:10],labels=data["Volume"][:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x1b7fbbf9070>,
# ...
#  [Text(1.0571481828455476, 0.30403572077365654, '142981500'),
#   Text(0.727282264988482, 0.82526390144803, '266677500'),
#   Text(0.15364799663306647, 1.0892163665363486, '151995000'),
#   Text(-0.48740639217958237, 0.9861211938004798, '268231500'),
#   Text(-0.9725609209780777, 0.5139311772857077, '467164500'),
#   Text(-1.0880600333702128, -0.16163342408800047, '426606000'),
#   Text(-0.7881886244149476, -0.7673061268769283, '194392500'),
#   Text(-0.1600257919047915, -1.088297636644151, '397764000'),
#   Text(0.5709487505285349, -0.940222061148272, '434943000'),
#   Text(1.0379531620323863, -0.36421591594406066, '260532000')])

# %%
pt.bar(data["Open"][:6],data["Adj Close"][:6])
# Out:
# <BarContainer object of 6 artists>
