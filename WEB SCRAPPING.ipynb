# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=e7acf495-359c-4915-9ade-56d84a490987"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
back_code=BeautifulSoup(response.text)

# %%
back_code
# Out:
# <!DOCTYPE html>
# ...

# %%
Shoes_name=back_code.select(".WKTcLC")

# %%
Shoes_name
# Out:
# [<a class="WKTcLC" href="/airson-sports-shoes-men-stylish-casual-sport-men-running-boys-running/p/itm0eb1b481cf361?pid=SHOGZBK2C7QEJYVK&amp;lid=LSTSHOGZBK2C7QEJYVK2KDCZE&amp;marketplace=FLIPKART&amp;q=shoes&amp;store=osp&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&amp;otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&amp;fm=organic&amp;iid=en_3zhTw0ZUoiD3IBWOk35MHUkN1fo7R5bFMy1DNYSY6baTa2lOfUwAqFwXYL9RwEkF_kD4T-6RtLZgv9VQFmR2Cw%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=22rqer32f40000001724668246204&amp;qH=b0a8b6f820479900" rel="noopener noreferrer" target="_blank" title="Sports shoes for men|Stylish Casual sport shoes for men |running shoes for boys Running Shoes For Men">Sports shoes for men|Stylish Casual sport shoes for men...</a>,
# ...

# %%
Price=back_code.select(".Nx9bqj")

# %%
Price
# Out:
# [<div class="Nx9bqj">₹399</div>,
#  <div class="Nx9bqj">₹712</div>,
#  <div class="Nx9bqj">₹828</div>,
#  <div class="Nx9bqj">₹839</div>,
#  <div class="Nx9bqj">₹1,023</div>,
#  <div class="Nx9bqj">₹319</div>,
#  <div class="Nx9bqj">₹712</div>,
#  <div class="Nx9bqj">₹1,679</div>,
#  <div class="Nx9bqj">₹864</div>,
#  <div class="Nx9bqj">₹624</div>,
#  <div class="Nx9bqj">₹998</div>,
#  <div class="Nx9bqj">₹619</div>,
#  <div class="Nx9bqj">₹699</div>,
#  <div class="Nx9bqj">₹319</div>,
#  <div class="Nx9bqj">₹2,999</div>,
#  <div class="Nx9bqj">₹2,672</div>,
#  <div class="Nx9bqj">₹901</div>,
#  <div class="Nx9bqj">₹1,186</div>,
#  <div class="Nx9bqj">₹769</div>,
#  <div class="Nx9bqj">₹1,999</div>,
#  <div class="Nx9bqj">₹599</div>,
#  <div class="Nx9bqj">₹1,007</div>,
#  <div class="Nx9bqj">₹3,149</div>,
#  <div class="Nx9bqj">₹299</div>,
#  <div class="Nx9bqj">₹319</div>,
#  <div class="Nx9bqj">₹699</div>,
#  <div class="Nx9bqj">₹1,115</div>,
#  <div class="Nx9bqj">₹1,505</div>,
# ...

# %%
FreeDelivery=back_code.select(".yiggsN")

# %%
FreeDelivery
# Out:
# [<div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
#  <div class="yiggsN O5Fpg8" style="color:#26A541;font-size:12px;font-weight:700">Lowest price in the year</div>,
#  <div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
#  <div class="yiggsN O5Fpg8" style="color:#26A541;font-size:12px;font-weight:700">Lowest Price in 15 days</div>,
#  <div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
#  <div class="yiggsN O5Fpg8" style="color:#26A541;font-size:12px;font-weight:700">Hot Deal</div>,
#  <div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
#  <div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
#  <div class="yiggsN" style="color:#000000;font-size:12px;font-weight:400">Free delivery</div>,
# ...

# %%
Shoesname=pd.DataFrame(columns=["Name"])

# %%
Shoesname["Price"]=Price

# %%
Shoesname
# Out:
#    Name     Price
# 0   NaN    [₹399]
# 1   NaN    [₹712]
# 2   NaN    [₹828]
# 3   NaN    [₹839]
# 4   NaN  [₹1,023]
# 5   NaN    [₹319]
# 6   NaN    [₹712]
# 7   NaN  [₹1,679]
# 8   NaN    [₹864]
# 9   NaN    [₹624]
# 10  NaN    [₹998]
# 11  NaN    [₹619]
# 12  NaN    [₹699]
# 13  NaN    [₹319]
# 14  NaN  [₹2,999]
# 15  NaN  [₹2,672]
# 16  NaN    [₹901]
# 17  NaN  [₹1,186]
# 18  NaN    [₹769]
# 19  NaN  [₹1,999]
# 20  NaN    [₹599]
# 21  NaN  [₹1,007]
# 22  NaN  [₹3,149]
# 23  NaN    [₹299]
# 24  NaN    [₹319]
# 25  NaN    [₹699]
# 26  NaN  [₹1,115]
# 27  NaN  [₹1,505]
# 28  NaN    [₹319]
# 29  NaN  [₹1,233]
# 30  NaN  [₹1,424]
# 31  NaN  [₹1,119]
# 32  NaN    [₹611]
# 33  NaN  [₹1,019]
# 34  NaN    [₹630]
# 35  NaN  [₹1,299]
# 36  NaN    [₹924]
# 37  NaN  [₹1,889]
# 38  NaN  [₹2,799]
# 39  NaN  [₹1,296]
# 40  NaN  [₹1,505]
# 41  NaN    [₹619]
# 42  NaN  [₹1,999]
# 43  NaN    [₹712]
# 44  NaN    [₹699]

# %%
Offers=pd.DataFrame(columns=["Name"])

# %%
Offers["FreeDelivery"]=FreeDelivery

# %%
Offers
# Out:
#    Name                FreeDelivery
# 0   NaN             [Free delivery]
# 1   NaN  [Lowest price in the year]
# 2   NaN             [Free delivery]
# 3   NaN   [Lowest Price in 15 days]
# 4   NaN             [Free delivery]
# ..  ...                         ...
# 64  NaN             [Free delivery]
# 65  NaN                  [Hot Deal]
# 66  NaN             [Free delivery]
# 67  NaN             [Free delivery]
# 68  NaN             [Free delivery]
#
# [69 rows x 2 columns]
